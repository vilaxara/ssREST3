# %%
import numpy as np
import json

class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return json.JSONEncoder.default(self, obj)

import sys

# old_path='/home/jayakrishna/work/scripts/analysis_class'
# if old_path in sys.path : sys.path.remove(old_path)

sys.path.append('../scripts')

from Block_analysis import *
from small_utilities import *
from importlib import reload
import plot
reload(plot)
# Out:
# <script>
#     let is_dark_theme = function () {
#         // Jupyter Lab
#         if ('jpThemeLight' in document.body.dataset)
#             return (document.body.dataset.jpThemeLight === "false");
#
#         // VS Code
#         if ('vscodeThemeKind' in document.body.dataset)
#             return document.body.dataset.vscodeThemeKind.includes('dark');
#
#         // Jupyter Book
#         if ('theme' in document.documentElement.dataset)
#             return document.documentElement.dataset.theme.includes('dark');
#
#         // Default
#         return window.matchMedia('(prefers-color-scheme: dark)').matches;
#     }
#
#     if (is_dark_theme()) {
#         document.documentElement.classList.add('dark');
#     }
#     else {
#         document.documentElement.classList.remove('dark');
#     }
# </script>
# ...

# %%
data_dir= '/data/ssREST3/Fasudil/REST2-1/'

nrep=10

sequence=  ['ASP121', 'ASN122', 'GLU123', 'ALA124', 'TYR125', 'GLU126', 'MET127', 'PRO128', 'SER129', 'GLU130', 'GLU131', 'GLY132', 'TYR133', 'GLN134', 'ASP135',
'TYR136', 'GLU137', 'PRO138', 'GLU139', 'ALA140']

files_dict={'p_cm':'p_contact_map.json',
            'l_cm':'l_contact_map.json',
            'bf':'bound_fraction.json',
            # 'ss' : {'helix' : 'helix_contant.json', 'sheet' : 'sheet_contant.json'},
            'rg' : 'rg.json',
            # 'rg_hist' : 'rg.json',
            # 'kd_time' : 'kd_bf_time.json',
            'lig_contacts' : 'avg_ligand_contacts.json',
            'lig_modes' : {'aro' : 'aro_interactions_bf.json',
                           'hyphob' : 'hyphob_interactions_bf.json',
                           'hbond' : 'hbond_interactions_bf.json',
                           'charge' : 'charge_contact_fraction_bf.json'},
            # 'rg_2d' : {'rg' : 'rg.json',
            #            'sa' : 'sa.json'},
            # 'sa' : 'sa.json',
            # 'phipsi' : {'helix' : 'alphabeta_alpharight.json',
            #             'sheet' : 'alphabeta_betasheet.json',
            #             'pp': 'alphabeta_ppII.json'},
            # 'ba' : 'bend_angle.json',
            
            }

out_dict={'p_cm':'p_contact_map',
        'l_cm':'l_contact_map',
        # 'kd':'kd_plot',
        # 'ss' : {'helix' : 'helix_contant',
        #         'sheet' : 'sheet_contant',
        #         'both' : 'secondary_structure'},
        # 'rg' : 'rg',
        # 'rg_hist' : 'rg_hist',
        # 'kd_time' : 'kd_time',
        # 'lig_contacts' : 'avg_ligand_contacts',
        # 'lig_modes' : {'togeather' :'ligand_modes_t',
        #                 'seperate' : 'ligand_modes_s'},
        # 'rg_2d' : 'rg_2d_sa',
        # 'sa' : 'sa_time',
        # 'phipsi' : 'ss_RMSD_probability',
        # 'ba' : 'bend_angle',    
        }

# %%
A = plot.plots(data_dir=data_dir, num_of_replicas=nrep, p_seq=sequence, json_files_dict=files_dict, out_files_dict=out_dict, 
               out_dir='./data/', offset=121)
# Out:
# Your temperatures are :
# ['300.000K' '313.825K' '328.286K' '343.414K' '359.239K' '375.794K'
#  '393.111K' '411.227K' '430.177K' '450.000K']

# %%
demux = False

# A.plot_l_cm(2show_fig=False, demux=demux, save_fig=False, plot_args_in={'fig_size': (10,24), 'nrows': 5, 'ncols': 2,})

# %%
A.plot_rg_temperature(show_fig=True, save_fig=False)

# %%
# A.print_time_splits(magic_num=78.1)

# %%
A.ligand_binding_profile(show_fig=True, save_fig=False, demux=demux)
# Out:
# /data/ssREST3/Fasudil/../scripts/plot.py:421: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
# A.ligand_contacts(show_fig=True, save_fig=False, demux=True, plot_args_in={'cmap': 'tab20c'})

# %%
A.bf_vs_replica(show_fig=True, save_fig=False, demux=demux)
