# %%
import numpy as np
import json
import sys
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return json.JSONEncoder.default(self, obj)
    

sys.path.insert(0, './scripts')

from Block_analysis import *
from small_utilities import *

import plot_old

# %%
data_dir= '/data/ssREST3/Fasudil/REST2-1/'

nrep=10
sequence=  ['ASP121', 'ASN122', 'GLU123', 'ALA124', 'TYR125', 'GLU126', 'MET127', 'PRO128', 'SER129', 'GLU130', 'GLU131', 'GLY132', 'TYR133', 'GLN134', 'ASP135',
'TYR136', 'GLU137', 'PRO138', 'GLU139', 'ALA140']

files_dict={'p_cm':'p_contact_map.json', 'l_cm':'l_contact_map.json', 'kd':'kd.json', 'ss' : {'helix' : 'helix_contant.json', 'sheet' : 'sheet_contant.json'}, 'rg' : 'rg.json',
            'rg_hist' : 'rg.json', 'kd_time' : 'kd_bf_time.json', 'lig_contacts' : 'avg_ligand_contacts.json', 'lig_modes' : {'aro' : 'aro_interactions_bf.json', 'hyphob' : 'hyphob_interactions_bf.json',
                                                                                                                             'hbond' : 'hbond_interactions_bf.json', 'charge' : 'charge_contact_fraction_bf.json'},
            'rg_2d' : {'rg' : 'rg.json', 'sa' : 'sa.json'}, 'sa' : 'sa.json', 'phipsi' : {'helix' : 'alphabeta_alpharight.json',
                                                                                          'sheet' : 'alphabeta_betasheet.json',
                                                                                          'pp': 'alphabeta_ppII.json'},
            'ba' : 'bend_angle.json'}
out_dict={'p_cm':'p_contact_map', 'l_cm':'l_contact_map', 'kd':'kd_plot', 'ss' : {'helix' : 'helix_contant', 'sheet' : 'sheet_contant', 'both' : 'secondary_structure'}, 'rg' : 'rg',
            'rg_hist' : 'rg_hist', 'kd_time' : 'kd_time', 'lig_contacts' : 'avg_ligand_contacts', 'lig_modes' : {'togeather' :'ligand_modes_t', 'seperate' : 'ligand_modes_s'},
            'rg_2d' : 'rg_2d_sa', 'sa' : 'sa_time', 'phipsi' : 'ss_RMSD_probability', 'ba' : 'bend_angle'}

A = plot_old.plots(data_dir=data_dir, num_of_replicas=nrep, p_seq=sequence, json_files_dict=files_dict, out_files_dict=out_dict, 
               out_dir='./data/', rows_cols={'rows' :2, 'cols' :5}, offset=121)
# Out:
# Your temperatures are :
# ['300.000' '313.825' '328.286' '343.414' '359.239' '375.794' '393.111'
#  '411.227' '430.177' '450.000']

# %%
demux = False

A.plot_l_cm(show_fig=False, demux=demux, save_fig=False, plot_args_in={'fig_size': (20,8)})

# %%
A.plot_lig_modes_grid(show_fig=False, demux=demux, save_fig=False)
