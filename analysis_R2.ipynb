# %%
import os
import sys

sys.path.insert(0, './scripts')

import structure_analysis_changes

# %%
ligand_rings = { 'fas' :  [[304,305,306,307,308,309,310,311,312,313]], 'lig47' : [[307, 308, 309, 311, 313, 314]]}
lig_hbond_donors= {'fas' : [[296,318],[296,331]], 'lig47' : [[329,330],[329,331]]}
Ligand_Pos_Charges={'fas': [296], 'lig47': [329] }
Ligand_Neg_Charges={ 'fas': [], 'lig47': []}


lig_dict=['fas','lig47']
lig=lig_dict[1]

# %%
base_dir='/data/ssREST3/xtc/'
# dir_list = [f'{base_dir}/REST2/fas_10/r/',
#             f'{base_dir}/REST2/fas_10/d/']
# dir_list = [f'{base_dir}/REST2/fas_20/r/',
#             f'{base_dir}/REST2/fas_20/d/']
# dir_list = [f'{base_dir}/REST2/lig47_10/r/',
#             f'{base_dir}/REST2/lig47_10/d/']
dir_list = [f'{base_dir}/REST2/lig47_20/r/',
            f'{base_dir}/REST2/lig47_20/d/']

# pdb= f'{base_dir}/REST2/pbc_fasudil.pdb'
pdb= f'{base_dir}/REST2/pbc_lig47.pdb'

tpr=None

# out_dir= '/data/ssREST3/Fasudil/REST2-1/'
# out_dir= '/data/ssREST3/Fasudil/REST2-2/'
# out_dir= '/data/ssREST3/Ligand47/REST2-1/'
out_dir= '/data/ssREST3/Ligand47/REST2-2/'

if not os.path.exists(out_dir):
    os.makedirs(out_dir)

nreps=[1,10,20,8,16]
reps=nreps[2]

pbc={'pbc' : True, 'traj_tag_in' : 'pbc_','traj_tag_out' : None, 'traj_type' : 'xtc'}
# pbc={'pbc' : False, 'traj_tag_in' : 'whole_','traj_tag_out' : 'pbc_', 'traj_type' : 'xtc'}

helix='/data/Jaya_Krishna/analysis_trajectories/async/rest/asyn_sa.pdb'
pp='/data/Jaya_Krishna/analysis_trajectories/async/rest/asyn_pp.pdb'

apo=False

residue_number_info={'p_s_n': 0,
                     'p_e_n': 19,
                     'l_e_i': 20,
                     'offset': 121}

analysis_list=['salpha_rmsd', 'pp_rmsd', 'rg' , 'ss' , 'ba' , 'kd' , 'charge', 'aro' , 'hyphob' , 'hbond', 'kd_bf_time', 'p_cm', 'l_cm']

# %%
structure_analysis_changes.ligand_interactions(rep_trajectory=dir_list[0],
                                                demux_trajectory=dir_list[1], 
                                                out_dir=out_dir,
                                                pbc_tpr=tpr ,
                                                nreps=reps,
                                                pdb=pdb, 
                                                helix_pdb=helix, 
                                                pp_pdb=pp, 
                                                ligand_rings=ligand_rings[lig], 
                                                ligand_residue_index=residue_number_info['l_e_i'], 
                                                prot_end_res_num=residue_number_info['p_e_n'], 
                                                prot_start_res_num=residue_number_info['p_s_n'], 
                                                stride=1, 
                                                offset=residue_number_info['offset'], 
                                                ligand_positive_charge_atoms=Ligand_Pos_Charges[lig], 
                                                ligand_negative_charge_atoms=Ligand_Neg_Charges[lig], 
                                                lig_hbond_donors=lig_hbond_donors[lig],
                                                rep_demux_switch="on",
                                                trj_break=10,
                                                apo=apo,
                                                pbc=pbc,
                                                analysis_list=analysis_list)
# Out:
# Initiating memory...
# Residues in the trjectory :
# ['NASP121' 'ASN122' 'GLU123' 'ALA124' 'TYR125' 'GLU126' 'MET127' 'PRO128'
#  'SER129' 'GLU130' 'GLU131' 'GLY132' 'TYR133' 'GLN134' 'ASP135' 'TYR136'
#  'GLU137' 'PRO138' 'GLU139' 'CALA140' 'L47141']
#
# Total number of residues excluding ions: 21
#
# Number of protein residues: 20
#
# Protien residues :
# ['NASP121' 'ASN122' 'GLU123' 'ALA124' 'TYR125' 'GLU126' 'MET127' 'PRO128'
#  'SER129' 'GLU130' 'GLU131' 'GLY132' 'TYR133' 'GLN134' 'ASP135' 'TYR136'
#  'GLU137' 'PRO138' 'GLU139' 'CALA140']
#
# Loading trajectory rep:0...
#
# Loading trajectory rep:1...
#
# Loading trajectory rep:2...
#
# Loading trajectory rep:3...
#
# Loading trajectory rep:4...
#
# Loading trajectory rep:5...
#
# Loading trajectory rep:6...
#
# Loading trajectory rep:7...
#
# Loading trajectory rep:8...
#
# Loading trajectory rep:9...
#
# Time taken : 00:00:01 seconds
#
# Analysis for ['rep:0', 'rep:1', 'rep:2', 'rep:3', 'rep:4', 'rep:5', 'rep:6', 'rep:7', 'rep:8', 'rep:9']
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:00 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:00 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:00 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:00 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:00 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:00 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:00 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:00 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:00 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:00 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:01 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:00 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:01 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:00 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:01 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:01 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:01 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:01 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:01 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:01 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating CONTACT MATRIX and Kd...
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# Time taken : 00:00:56 seconds
#
# Claculating charge...
#
# Time taken : 00:00:08 seconds
#
# Claculating aro...
#
# Time taken : 00:00:12 seconds
#
# Claculating hphob...
#
# Time taken : 00:00:09 seconds
#
# Claculating hbond...
#
# Time taken : 00:00:26 seconds
#
# Claculating protein contact matrix...
#
# Time taken : 00:00:09 seconds
#
# Claculating ligand-protein dual contact matrix...
#
# Time taken : 00:00:09 seconds
#
# Loading trajectory rep:10...
#
# Loading trajectory rep:11...
#
# Loading trajectory rep:12...
#
# Loading trajectory rep:13...
#
# Loading trajectory rep:14...
#
# Loading trajectory rep:15...
#
# Loading trajectory rep:16...
#
# Loading trajectory rep:17...
#
# Loading trajectory rep:18...
#
# Loading trajectory rep:19...
#
# Time taken : 00:00:01 seconds
#
# Analysis for ['rep:10', 'rep:11', 'rep:12', 'rep:13', 'rep:14', 'rep:15', 'rep:16', 'rep:17', 'rep:18', 'rep:19']
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:01 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:01 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:01 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:02 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:02 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:02 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:02 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:02 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:02 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:02 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:02 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:02 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:02 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:02 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:02 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating CONTACT MATRIX and Kd...
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# Time taken : 00:01:02 seconds
#
# Claculating charge...
#
# Time taken : 00:00:09 seconds
#
# Claculating aro...
#
# Time taken : 00:00:13 seconds
#
# Claculating hphob...
#
# Time taken : 00:00:10 seconds
#
# Claculating hbond...
#
# Time taken : 00:00:27 seconds
#
# Claculating protein contact matrix...
#
# Time taken : 00:00:09 seconds
#
# Claculating ligand-protein dual contact matrix...
#
# Time taken : 00:00:08 seconds
#
# Loading trajectory demux:0...
#
# Loading trajectory demux:1...
#
# Loading trajectory demux:2...
#
# Loading trajectory demux:3...
#
# Loading trajectory demux:4...
#
# Loading trajectory demux:5...
#
# Loading trajectory demux:6...
#
# Loading trajectory demux:7...
#
# Loading trajectory demux:8...
#
# Loading trajectory demux:9...
#
# Time taken : 00:00:01 seconds
#
# Analysis for ['demux:0', 'demux:1', 'demux:2', 'demux:3', 'demux:4', 'demux:5', 'demux:6', 'demux:7', 'demux:8', 'demux:9']
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:04 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:03 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:04 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:04 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:04 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:04 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:04 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:04 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:00 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:04 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:04 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:01 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:04 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:04 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:01 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating CONTACT MATRIX and Kd...
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# Time taken : 00:01:03 seconds
#
# Claculating charge...
#
# Time taken : 00:00:09 seconds
#
# Claculating aro...
#
# Time taken : 00:00:14 seconds
#
# Claculating hphob...
#
# Time taken : 00:00:09 seconds
#
# Claculating hbond...
#
# Time taken : 00:00:26 seconds
#
# Claculating protein contact matrix...
#
# Time taken : 00:00:10 seconds
#
# Claculating ligand-protein dual contact matrix...
#
# Time taken : 00:00:08 seconds
#
# Loading trajectory demux:10...
#
# Loading trajectory demux:11...
#
# Loading trajectory demux:12...
#
# Loading trajectory demux:13...
#
# Loading trajectory demux:14...
#
# Loading trajectory demux:15...
#
# Loading trajectory demux:16...
#
# Loading trajectory demux:17...
#
# Loading trajectory demux:18...
#
# Loading trajectory demux:19...
#
# Time taken : 00:00:01 seconds
#
# Analysis for ['demux:10', 'demux:11', 'demux:12', 'demux:13', 'demux:14', 'demux:15', 'demux:16', 'demux:17', 'demux:18', 'demux:19']
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:04 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:04 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Time taken : 00:00:01 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:01 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:01 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:01 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:01 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:01 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Time taken : 00:00:01 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:06 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Time taken : 00:00:01 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:06 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:05 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:01 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating Alpha-Helix RMSD...
#
# Time taken : 00:00:06 seconds
#
# Claculating Poly-prolein RMSD...
#
# Time taken : 00:00:06 seconds
#
# Claculating Rg...
#
# Time taken : 00:00:00 seconds
#
# Claculating SS propenseties...
#
# Warning: Use more data
# Warning: Use more data
# Warning: Use more data
# Time taken : 00:00:01 seconds
#
# Claculating average bend angle...
#
# Will compute the average bend angle between the below protien residues. Please CHECK!
# NASP121-CA, 4
# GLU131-CA, 148
# CALA140-CA, 285
#
#
# Time taken : 00:00:00 seconds
#
# Claculating CONTACT MATRIX and Kd...
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# /data/ssREST3/./scripts/structure_analysis_changes.py:747: RuntimeWarning: divide by zero encountered in divide
#   return((1-bound)*conc/bound)
# Time taken : 00:01:04 seconds
#
# Claculating charge...
#
# Time taken : 00:00:10 seconds
#
# Claculating aro...
#
# Time taken : 00:00:14 seconds
#
# Claculating hphob...
#
# Time taken : 00:00:10 seconds
#
# Claculating hbond...
#
# Time taken : 00:00:27 seconds
#
# Claculating protein contact matrix...
#
# Time taken : 00:00:10 seconds
#
# Claculating ligand-protein dual contact matrix...
#
# Time taken : 00:00:08 seconds
#
# All Done in 00:04:40 seconds
